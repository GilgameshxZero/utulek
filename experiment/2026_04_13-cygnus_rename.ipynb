# %%
# %load_ext autoreload
# %autoreload 2

# %%
import utulek

utulek.platform.import_globals_notebook(globals())
# Out:
# base_module = utulek
# IS_NOTEBOOK_KERNEL_CODE = True
# NOTEBOOK_NAME = 2026_04_13-cygnus_rename.ipynb
# ASSETS_PATH = /home/gilgamesh/main.syncthing/utulek/experiment/2026_04_13-cygnus_rename.ipynb.assets/
# Loaded `/home/gilgamesh/main.syncthing/utulek/experiment/.env`.
# torch: []
# tf:
# jax: [CpuDevice(id=0)]
# 2026-04-13 13:45:34.838082: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
glob.glob("../../cygnus/entry/*.md.assets")
# Out:
# []

# %%
pattern = re.compile(r"(\d+).md.assets")

for i in glob.glob("../../cygnus/entry/*.md.assets"):
	filename_len = len(i.split("/")[-1])
	pathname = i[:-filename_len]
	filename = i[-filename_len:]
	match = pattern.fullmatch(filename)
	if not match:
		continue
	groups = match.groups()
	new_name = f"{groups[0]}.md.asset"
	print(pathname + filename, pathname + new_name)
	os.rename(pathname + filename, pathname + new_name)
# Out:
# ../../cygnus/entry/329.md.assets ../../cygnus/entry/329.md.asset
# ../../cygnus/entry/395.md.assets ../../cygnus/entry/395.md.asset
# ../../cygnus/entry/320.md.assets ../../cygnus/entry/320.md.asset
# ../../cygnus/entry/251.md.assets ../../cygnus/entry/251.md.asset
# ../../cygnus/entry/213.md.assets ../../cygnus/entry/213.md.asset
# ../../cygnus/entry/250.md.assets ../../cygnus/entry/250.md.asset
# ../../cygnus/entry/404.md.assets ../../cygnus/entry/404.md.asset
# ../../cygnus/entry/325.md.assets ../../cygnus/entry/325.md.asset
# ../../cygnus/entry/330.md.assets ../../cygnus/entry/330.md.asset
# ../../cygnus/entry/822.md.assets ../../cygnus/entry/822.md.asset
# ../../cygnus/entry/205.md.assets ../../cygnus/entry/205.md.asset
# ../../cygnus/entry/200.md.assets ../../cygnus/entry/200.md.asset
# ../../cygnus/entry/202.md.assets ../../cygnus/entry/202.md.asset
# ../../cygnus/entry/336.md.assets ../../cygnus/entry/336.md.asset
# ../../cygnus/entry/436.md.assets ../../cygnus/entry/436.md.asset
# ../../cygnus/entry/337.md.assets ../../cygnus/entry/337.md.asset
# ../../cygnus/entry/278.md.assets ../../cygnus/entry/278.md.asset
# ../../cygnus/entry/415.md.assets ../../cygnus/entry/415.md.asset
# ../../cygnus/entry/818.md.assets ../../cygnus/entry/818.md.asset
# ../../cygnus/entry/844.md.assets ../../cygnus/entry/844.md.asset
# ../../cygnus/entry/388.md.assets ../../cygnus/entry/388.md.asset
# ../../cygnus/entry/478.md.assets ../../cygnus/entry/478.md.asset
# ../../cygnus/entry/116.md.assets ../../cygnus/entry/116.md.asset
# ../../cygnus/entry/273.md.assets ../../cygnus/entry/273.md.asset
# ../../cygnus/entry/318.md.assets ../../cygnus/entry/318.md.asset
# ../../cygnus/entry/227.md.assets ../../cygnus/entry/227.md.asset
# ../../cygnus/entry/465.md.assets ../../cygnus/entry/465.md.asset
# ../../cygnus/entry/828.md.assets ../../cygnus/entry/828.md.asset
# ../../cygnus/entry/372.md.assets ../../cygnus/entry/372.md.asset
# ../../cygnus/entry/260.md.assets ../../cygnus/entry/260.md.asset
# ../../cygnus/entry/729.md.assets ../../cygnus/entry/729.md.asset
# ../../cygnus/entry/201.md.assets ../../cygnus/entry/201.md.asset
# ../../cygnus/entry/101.md.assets ../../cygnus/entry/101.md.asset
# ../../cygnus/entry/317.md.assets ../../cygnus/entry/317.md.asset
# ../../cygnus/entry/487.md.assets ../../cygnus/entry/487.md.asset
# ../../cygnus/entry/864.md.assets ../../cygnus/entry/864.md.asset
# ../../cygnus/entry/198.md.assets ../../cygnus/entry/198.md.asset
# ../../cygnus/entry/475.md.assets ../../cygnus/entry/475.md.asset
# ../../cygnus/entry/282.md.assets ../../cygnus/entry/282.md.asset
# ../../cygnus/entry/258.md.assets ../../cygnus/entry/258.md.asset
# ../../cygnus/entry/189.md.assets ../../cygnus/entry/189.md.asset
# ../../cygnus/entry/837.md.assets ../../cygnus/entry/837.md.asset
# ../../cygnus/entry/309.md.assets ../../cygnus/entry/309.md.asset
# ../../cygnus/entry/829.md.assets ../../cygnus/entry/829.md.asset
# ../../cygnus/entry/306.md.assets ../../cygnus/entry/306.md.asset
# ../../cygnus/entry/95.md.assets ../../cygnus/entry/95.md.asset
# ../../cygnus/entry/319.md.assets ../../cygnus/entry/319.md.asset
# ../../cygnus/entry/470.md.assets ../../cygnus/entry/470.md.asset
# ../../cygnus/entry/256.md.assets ../../cygnus/entry/256.md.asset
# ../../cygnus/entry/413.md.assets ../../cygnus/entry/413.md.asset
# ../../cygnus/entry/304.md.assets ../../cygnus/entry/304.md.asset
# ../../cygnus/entry/462.md.assets ../../cygnus/entry/462.md.asset
# ../../cygnus/entry/426.md.assets ../../cygnus/entry/426.md.asset
# ../../cygnus/entry/270.md.assets ../../cygnus/entry/270.md.asset
# ../../cygnus/entry/823.md.assets ../../cygnus/entry/823.md.asset
# ../../cygnus/entry/127.md.assets ../../cygnus/entry/127.md.asset
# ../../cygnus/entry/321.md.assets ../../cygnus/entry/321.md.asset
# ../../cygnus/entry/408.md.assets ../../cygnus/entry/408.md.asset
# ../../cygnus/entry/551.md.assets ../../cygnus/entry/551.md.asset
# ../../cygnus/entry/323.md.assets ../../cygnus/entry/323.md.asset
# ../../cygnus/entry/860.md.assets ../../cygnus/entry/860.md.asset
# ../../cygnus/entry/847.md.assets ../../cygnus/entry/847.md.asset
# ../../cygnus/entry/400.md.assets ../../cygnus/entry/400.md.asset
# ../../cygnus/entry/5.md.assets ../../cygnus/entry/5.md.asset
# ../../cygnus/entry/285.md.assets ../../cygnus/entry/285.md.asset
# ../../cygnus/entry/268.md.assets ../../cygnus/entry/268.md.asset
# ../../cygnus/entry/428.md.assets ../../cygnus/entry/428.md.asset
# ../../cygnus/entry/194.md.assets ../../cygnus/entry/194.md.asset
# ../../cygnus/entry/347.md.assets ../../cygnus/entry/347.md.asset
# ../../cygnus/entry/226.md.assets ../../cygnus/entry/226.md.asset
# ../../cygnus/entry/272.md.assets ../../cygnus/entry/272.md.asset
# ../../cygnus/entry/852.md.assets ../../cygnus/entry/852.md.asset
