# %%
import utulek

utulek.show_img_ds(*utulek.fetch_tfds_img_ds("mnist", "train[:1024]"),
                   shape=(2, 5))
utulek.show_img_ds(*utulek.fetch_tfds_img_ds("cifar10", "train[:1024]"),
                   labels=utulek.fetch_tfds_img_ds_labels("cifar10"),
                   shape=(2, 5))
# Out:
# 2023-10-03 01:20:35.985786: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/gilgamesh/main.syncthing/utulek/.venv/lib/python3.9/site-packages/cv2/../../lib64:
# 2023-10-03 01:20:35.985824: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-10-03 01:20:36.040468: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# Interesting MNIST IDs: 889.
# Interesting CIFAR10 IDs: 175.
utulek.show_img_ds(
    *utulek.fetch_tfds_img_ds("mnist", "train[:1024]"),
    samples=((889,),))
utulek.show_img_ds(
    *utulek.fetch_tfds_img_ds("cifar10", "train[:1024]"),
    labels=utulek.fetch_tfds_img_ds_labels("cifar10"),
    samples=((175,),))

# %%
utulek.fetch_tfds_img_ds_labels("cifar10")
