# %%
# %load_ext autoreload
# %autoreload 2

import utulek

utulek.platform.import_globals_notebook(globals())
# Out:
# base_module = utulek
# IS_NOTEBOOK_KERNEL_CODE = True
# NOTEBOOK_NAME = c:\Users\0\main.syncthing\utulek\experiment\2026_04_28-platform-gilgamesh-44.ipynb
# ASSETS_PATH = c:\Users\0\main.ipynb.assets/
# torch: ['NVIDIA GeForce GTX 1080 Ti']
# tf: /device:GPU:0
# jax: [CudaDevice(id=0)]
# E0428 07:55:55.705147 2289829 cuda_executor.cc:1526] Could not get kernel mode driver version: (INVALID_ARGUMENT: Version does not match the format X.Y.Z)
# E0428 07:55:55.706540 2289600 cuda_executor.cc:1526] Could not get kernel mode driver version: (INVALID_ARGUMENT: Version does not match the format X.Y.Z)
