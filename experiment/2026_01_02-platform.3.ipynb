# %%
# %load_ext autoreload
# %autoreload 2

# %%
import utulek

utulek.platform.import_globals(globals())
# Out:
# c:\Users\0\main.syncthing\utulek\.venv\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# Loaded `c:\Users\0\main.syncthing\utulek\experiment\.env`.
# ASSETS_PATH: c:\Users\0\main.syncthing\utulek\experiment\2026_01_02-platform.ipynb.assets\
# torch: []
# tf:
# jax: [CpuDevice(id=0)]
