# %%
# %load_ext autoreload
# %autoreload 2

import utulek

utulek.platform.import_globals_notebook(globals())
# Out:
# base_module = utulek
# [transformers] Disabling PyTorch because PyTorch >= 2.4 is required but found 2.2.2
# [transformers] PyTorch was not found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# IS_NOTEBOOK_KERNEL_CODE = True
# NOTEBOOK_NAME = 2026_04_28-platform-gilgamesh-43.ipynb
# ASSETS_PATH = /Users/gilgamesh/main.syncthing/utulek/experiment/2026_04_28-platform-gilgamesh-43.ipynb.assets/
# Loaded `/Users/gilgamesh/main.syncthing/utulek/experiment/.env`.
# torch: []
# tf:
# jax: [CpuDevice(id=0)]
