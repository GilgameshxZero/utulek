# %%
# %load_ext autoreload
# %autoreload 2

# %%
import utulek

utulek.platform.import_globals(globals())
# Out:
# Loaded `/home/gilgamesh/main.syncthing/utulek/experiment/.env`.
# ASSETS_PATH: /home/gilgamesh/main.syncthing/utulek/experiment/experiment/.ipynb.assets/
# torch: []
# tf:
# jax: [CpuDevice(id=0)]
# 2026-01-02 21:29:21.030034: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
