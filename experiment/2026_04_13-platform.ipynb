# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import utulek

utulek.platform.import_globals_notebook(globals())
# Out:
# base_module = utulek
# Matplotlib is building the font cache; this may take a moment.
# IS_NOTEBOOK_KERNEL_CODE = True
# NOTEBOOK_NAME = 2026_04_13-platform.ipynb
# ASSET_PATH = /home/gilgamesh/main.syncthing/utulek/experiment/2026_04_13-platform.ipynb.asset/
# Loaded `/home/gilgamesh/main.syncthing/utulek/experiment/.env`.
# torch: ['NVIDIA GeForce GTX 1080 Ti']
# tf: /device:GPU:0
# jax: [CudaDevice(id=0)]
