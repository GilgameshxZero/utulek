# %%
# %load_ext autoreload
# %autoreload 2

# %%
import utulek

utulek.platform.import_globals_notebook(globals())
# Out:
# base_module = utulek
# /home/gilgamesh/main.syncthing/utulek/.venv/lib/python3.11/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# IS_NOTEBOOK_KERNEL_CODE = True
# NOTEBOOK_NAME = 2026_04_13-platform.ipynb
# ASSETS_PATH = /home/gilgamesh/main.syncthing/utulek/experiment/2026_04_13-platform.ipynb.assets/
# Loaded `/home/gilgamesh/main.syncthing/utulek/experiment/.env`.
# torch: ['NVIDIA GeForce GTX 1080 Ti']
# tf: /device:GPU:0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776088851.345667  564980 gpu_device.cc:2020] Created device /device:GPU:0 with 9836 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1
# jax: [CudaDevice(id=0)]
