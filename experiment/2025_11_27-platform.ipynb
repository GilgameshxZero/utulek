# %%
# CUDA version.
! nvcc -V
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2025 NVIDIA Corporation
# Built on Tue_May_27_02:21:03_PDT_2025
# Cuda compilation tools, release 12.9, V12.9.86
# Build cuda_12.9.r12.9/compiler.36037853_0

# %%
# cuDNN version.
! cat /usr/include/cudnn_version.h | grep CUDNN_MAJOR -A 2
# Out:
# #define CUDNN_MAJOR 9
# #define CUDNN_MINOR 11
# #define CUDNN_PATCHLEVEL 0
# --
# #define CUDNN_VERSION (CUDNN_MAJOR * 10000 + CUDNN_MINOR * 100 + CUDNN_PATCHLEVEL)
#
# /* cannot use constexpr here since this is a C-only file */

# %%
import torch

try:
    print(torch.cuda.is_available())
    print([torch.cuda.get_device_name(i) for i in range(torch.cuda.device_count())])
    print(torch.cuda.FloatTensor())
except:
    pass
# Out:
# True
# ['Juice GPU [NVIDIA GeForce GTX 1080 Ti]']
# tensor([], device='cuda:0')

# %%
import tensorflow as tf

print(tf.test.gpu_device_name())
# Out:
# 2025-11-28 00:15:12.913619: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764314113.098362  142661 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764314113.174206  142661 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764314113.560123  142661 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764314113.560208  142661 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764314113.560211  142661 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764314113.560215  142661 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-28 00:15:14.347808: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /device:GPU:0
# 2025-11-28 00:15:26.957337: E external/local_xla/xla/stream_executor/cuda/cuda_context.cc:141] The primary context is active and has a different flag set (20) than the desired flag set (0).
# I0000 00:00:1764314127.067171  142661 gpu_device.cc:2019] Created device /device:GPU:0 with 9691 MB memory:  -> device: 0, name: Juice GPU [NVIDIA GeForce GTX 1080 Ti], pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
import jax

print(jax.local_devices())
# Out:
# [CpuDevice(id=0)]

# %%
! pip freeze
# Out:
# /home/gilgamesh/.pyenv/versions/3.11.9/lib/python3.11/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# absl-py==2.3.1
# adversarial-robustness-toolbox==1.20.1
# aiofiles==25.1.0
# aiohappyeyeballs==2.6.1
# aiohttp==3.13.2
# aiosignal==1.4.0
# annotated-types==0.7.0
# anyio==4.11.0
# argon2-cffi==25.1.0
# argon2-cffi-bindings==25.1.0
# array_record==0.8.3
# arrow==1.4.0
# astroid==4.0.2
# asttokens==3.0.1
# astunparse==1.6.3
# async-lru==2.0.5
# attrs==25.4.0
# autobahn==24.4.2
# Automat==25.4.16
# autopep8==2.3.2
# babel==2.17.0
# beautifulsoup4==4.14.2
# bleach==6.3.0
# blinker==1.9.0
# brotli==1.2.0
# certifi==2025.11.12
# cffi==2.0.0
# charset-normalizer==3.4.4
# chex==0.1.90
# click==8.3.1
# cloudpickle==3.1.2
# clu==0.0.12
# cmake==4.1.3
# colormath==3.0.0
# comm==0.2.3
# constantly==23.10.4
# contourpy==1.3.3
# cox==0.1.post3
# cryptography==46.0.3
# cycler==0.12.1
# datasets==4.4.1
# debugpy==1.8.17
# decorator==5.2.1
# defusedxml==0.7.1
# dill==0.4.0
# distro==1.9.0
# dm-tree==0.1.9
# docstring_parser==0.17.0
# einops==0.8.1
# etils==1.13.0
# executing==2.2.1
# fastjsonschema==2.21.2
# filelock==3.20.0
# Flask==3.1.2
# flatbuffers==25.9.23
# flax==0.11.2
# fonttools==4.60.1
# fqdn==1.5.1
# frozendict==2.4.7
# frozenlist==1.8.0
# fsspec==2025.10.0
# gast==0.6.0
# gdown==5.2.0
# gitdb==4.0.12
# GitPython==3.1.45
# google-pasta==0.2.0
# googleapis-common-protos==1.72.0
# grpcio==1.76.0
# h11==0.16.0
# h5py==3.15.1
# hf-xet==1.2.0
# httpcore==1.0.9
# httpx==0.28.1
# huggingface-hub==0.36.0
# humanize==4.14.0
# hyperlink==21.0.0
# idna==3.11
# immutabledict==4.2.2
# importlib_resources==6.5.2
# incremental==24.7.2
# inflate64==1.0.3
# ipykernel==7.1.0
# ipython==9.7.0
# ipython_pygments_lexers==1.1.1
# ipywidgets==8.1.8
# isoduration==20.11.0
# isort==7.0.0
# iterable-io==1.0.0
# itsdangerous==2.2.0
# jax==0.6.2
# jax-cuda12-pjrt==0.6.2
# jax-cuda12-plugin==0.6.2
# jaxlib==0.6.2
# jedi==0.19.2
# Jinja2==3.1.6
# jiter==0.12.0
# joblib==1.5.2
# json5==0.12.1
# jsonpointer==3.0.0
# jsonschema==4.25.1
# jsonschema-specifications==2025.9.1
# jupyter-events==0.12.0
# jupyter-lsp==2.3.0
# jupyter_client==8.6.3
# jupyter_core==5.9.1
# jupyter_server==2.17.0
# jupyter_server_terminals==0.5.3
# jupyterlab==4.5.0
# jupyterlab_pygments==0.3.0
# jupyterlab_server==2.28.0
# jupyterlab_widgets==3.0.16
# keras==3.12.0
# kiwisolver==1.4.9
# lark==1.3.1
# libclang==18.1.1
# lit==18.1.8
# lxml==6.0.2
# magic-wormhole==0.21.1
# Markdown==3.10
# markdown-it-py==4.0.0
# MarkupSafe==3.0.3
# matplotlib==3.10.7
# matplotlib-inline==0.2.1
# mccabe==0.7.0
# mdurl==0.1.2
# mistune==3.1.4
# ml_collections==1.1.0
# ml_dtypes==0.5.4
# mpmath==1.3.0
# msgpack==1.1.2
# multidict==6.7.0
# multiprocess==0.70.18
# multivolumefile==0.2.3
# namex==0.1.0
# narwhals==2.12.0
# nbclient==0.10.2
# nbconvert==7.16.6
# nbformat==5.10.4
# nest-asyncio==1.6.0
# networkx==3.5
# neural-tangents==0.6.5
# notebook_shim==0.2.4
# numpy==2.1.3
# nvidia-cublas-cu11==11.10.3.66
# nvidia-cublas-cu12==12.9.1.4
# nvidia-cuda-cupti-cu11==11.7.101
# nvidia-cuda-cupti-cu12==12.9.79
# nvidia-cuda-nvcc-cu12==12.9.86
# nvidia-cuda-nvrtc-cu11==11.7.99
# nvidia-cuda-nvrtc-cu12==12.9.86
# nvidia-cuda-runtime-cu11==11.7.99
# nvidia-cuda-runtime-cu12==12.9.79
# nvidia-cudnn-cu11==8.5.0.96
# nvidia-cudnn-cu12==9.16.0.29
# nvidia-cufft-cu11==10.9.0.58
# nvidia-cufft-cu12==11.4.1.4
# nvidia-curand-cu11==10.2.10.91
# nvidia-cusolver-cu11==11.4.0.1
# nvidia-cusolver-cu12==11.7.5.82
# nvidia-cusparse-cu11==11.7.4.91
# nvidia-cusparse-cu12==12.5.10.65
# nvidia-ml-py==13.580.82
# nvidia-nccl-cu11==2.14.3
# nvidia-nccl-cu12==2.28.9
# nvidia-nvjitlink-cu12==12.9.86
# nvidia-nvshmem-cu12==3.4.5
# nvidia-nvtx-cu11==11.7.91
# nvidia-pyindex==1.0.9
# openai==2.8.1
# opencv-python==4.12.0.88
# opt_einsum==3.4.0
# optax==0.2.6
# optree==0.18.0
# orbax-checkpoint==0.11.28
# outcome==1.3.0.post0
# overrides==7.7.0
# packaging==25.0
# pandas==2.3.3
# pandocfilters==1.5.1
# parso==0.8.5
# pexpect==4.9.0
# pillow==12.0.0
# platformdirs==4.5.0
# plotly==6.5.0
# prometheus_client==0.23.1
# promise==2.3
# prompt_toolkit==3.0.52
# propcache==0.4.1
# protobuf==5.29.5
# psutil==7.1.3
# ptyprocess==0.7.0
# pure_eval==0.2.3
# py3nvml==0.2.7
# py7zr==1.0.0
# pyarrow==22.0.0
# pyasn1==0.6.1
# pyasn1_modules==0.4.2
# pybcj==1.0.6
# pycodestyle==2.14.0
# pycparser==2.23
# pycryptodomex==3.23.0
# pydantic==2.12.4
# pydantic_core==2.41.5
# Pygments==2.19.2
# pylint==4.0.3
# PyNaCl==1.6.1
# pynvml==13.0.1
# pyOpenSSL==25.3.0
# pyparsing==3.2.5
# pyppmd==1.2.0
# PySocks==1.7.1
# python-dateutil==2.9.0.post0
# python-dotenv==1.2.1
# python-json-logger==4.0.0
# pytz==2025.2
# PyYAML==6.0.3
# pyzmq==27.1.0
# pyzstd==0.18.0
# qrcode==8.2
# referencing==0.37.0
# regex==2025.11.3
# requests==2.32.5
# rfc3339-validator==0.1.4
# rfc3986-validator==0.1.1
# rfc3987-syntax==1.1.0
# rich==14.2.0
# rpds-py==0.29.0
# safetensors==0.7.0
# scikit-learn==1.7.2
# scipy==1.16.3
# selenium==4.38.0
# Send2Trash==1.8.3
# service-identity==24.2.0
# simple-parsing==0.1.7
# simplejson==3.20.2
# six==1.17.0
# smmap==5.0.2
# sniffio==1.3.1
# sortedcontainers==2.4.0
# soupsieve==2.8
# spake2==0.9
# stack-data==0.6.3
# sympy==1.14.0
# tensorboard==2.19.0
# tensorboard-data-server==0.7.2
# tensorflow==2.19.0
# tensorflow-datasets==4.9.9
# tensorflow-io-gcs-filesystem==0.37.1
# tensorflow-metadata==1.17.2
# tensorflow-probability==0.25.0
# tensorstore==0.1.79
# termcolor==3.2.0
# terminado==0.18.1
# texttable==1.7.0
# tf2jax==0.3.7
# tf_keras==2.19.0
# threadpoolctl==3.6.0
# tinycss2==1.4.0
# tokenizers==0.22.1
# toml==0.10.2
# tomlkit==0.13.3
# toolz==1.1.0
# torch==2.0.1
# torchaudio==2.0.2
# torchvision==0.15.2
# tornado==6.5.2
# tqdm==4.67.1
# traitlets==5.14.3
# transformers==4.57.1
# treescope==0.1.10
# trio==0.32.0
# trio-websocket==0.12.2
# triton==2.0.0
# Twisted==25.5.0
# txaio==25.9.2
# txtorcon==24.8.0
# typing-inspection==0.4.2
# typing_extensions==4.15.0
# tzdata==2025.2
# uri-template==1.3.0
# urllib3==2.5.0
# -e git+ssh://git@github.com/GilgameshxZero/utulek.git@46eb70db17e90e76c73cf29e743a9c5fb3c03e8d#egg=utulek
# wcwidth==0.2.14
# webcolors==25.10.0
# webencodings==0.5.1
# websocket-client==1.9.0
# Werkzeug==3.1.3
# widgetsnbextension==4.0.15
# wrapt==2.0.1
# wsproto==1.3.1
# xmltodict==1.0.2
# xxhash==3.6.0
# yapf==0.43.0
# yarl==1.22.0
# zipp==3.23.0
# zipstream-ng==1.9.0
# zope.interface==8.1.1
# zstandard==0.25.0

# %%
print("hello world!")
# Out:
# hello world!

# %%
import tqdm

for i in tqdm.tqdm(range(100)):
    pass
# Out:
# 100%|█████████████████████████████████████| 100/100 [00:00<00:00, 363143.20it/s]
