# %%
# %load_ext autoreload
# %autoreload 2

# %%
import utulek

utulek.platform.import_globals(globals())
# Out:
# /home/gilgamesh/main.syncthing/utulek/.venv/lib/python3.11/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# /home/gilgamesh/main.syncthing/utulek/experiment/2026_01_02-platform.ipynb.assets/
# torch: ['NVIDIA GeForce GTX 1080 Ti']
# tf: /device:GPU:0
# jax: [CudaDevice(id=0)]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1767412843.239794  357697 gpu_device.cc:2020] Created device /device:GPU:0 with 9820 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1
