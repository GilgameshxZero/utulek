# %%
# %load_ext autoreload
# %autoreload 2

# %%
import utulek

utulek.platform.import_globals_notebook(globals())
# Out:
# base_module = utulek
# IS_NOTEBOOK_KERNEL_CODE = True
# NOTEBOOK_NAME = 2026_02_12-cygnus_paths.ipynb
# ASSETS_PATH = /home/gilgamesh/main.syncthing/utulek/experiment/2026_02_12-cygnus_paths.ipynb.assets/
# Loaded `/home/gilgamesh/main.syncthing/utulek/experiment/.env`.
# torch: []
# tf:
# jax: [CpuDevice(id=0)]
# 2026-02-12 19:43:22.072122: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
glob.glob("../../cygnus/entries/*-assets")
# Out:
# ['../../cygnus/entries/5.md-assets',
#  '../../cygnus/entries/399.md-assets',
#  '../../cygnus/entries/470.md-assets',
#  '../../cygnus/entries/249.md-assets',
#  '../../cygnus/entries/455.md-assets',
#  '../../cygnus/entries/201.md-assets',
#  '../../cygnus/entries/202.md-assets',
#  '../../cygnus/entries/230.md-assets',
#  '../../cygnus/entries/258.md-assets',
#  '../../cygnus/entries/436.md-assets',
#  '../../cygnus/entries/199.md-assets',
#  '../../cygnus/entries/405.md-assets',
#  '../../cygnus/entries/309.md-assets',
#  '../../cygnus/entries/315.md-assets',
#  '../../cygnus/entries/95.md-assets',
#  '../../cygnus/entries/404.md-assets',
#  '../../cygnus/entries/339.md-assets',
#  '../../cygnus/entries/462.md-assets',
#  '../../cygnus/entries/204.md-assets',
#  '../../cygnus/entries/281.md-assets',
#  '../../cygnus/entries/306.md-assets',
#  '../../cygnus/entries/250.md-assets',
#  '../../cygnus/entries/213.md-assets',
#  '../../cygnus/entries/372.md-assets',
#  '../../cygnus/entries/400.md-assets',
#  '../../cygnus/entries/465.md-assets',
#  '../../cygnus/entries/330.md-assets',
#  '../../cygnus/entries/466.md-assets',
#  '../../cygnus/entries/321.md-assets',
#  '../../cygnus/entries/200.md-assets',
#  '../../cygnus/entries/475.md-assets',
#  '../../cygnus/entries/181.md-assets',
#  '../../cygnus/entries/278.md-assets',
#  '../../cygnus/entries/623.md-assets',
#  '../../cygnus/entries/551.md-assets',
#  '../../cygnus/entries/329.md-assets',
#  '../../cygnus/entries/274.md-assets',
#  '../../cygnus/entries/260.md-assets',
#  '../../cygnus/entries/478.md-assets',
#  '../../cygnus/entries/710.md-assets',
#  '../../cygnus/entries/264.md-assets',
#  '../../cygnus/entries/336.md-assets',
#  '../../cygnus/entries/337.md-assets',
#  '../../cygnus/entries/279.md-assets',
#  '../../cygnus/entries/182.md-assets',
#  '../../cygnus/entries/347.md-assets',
#  '../../cygnus/entries/101.md-assets',
#  '../../cygnus/entries/282.md-assets',
#  '../../cygnus/entries/254.md-assets',
#  '../../cygnus/entries/322.md-assets',
#  '../../cygnus/entries/270.md-assets',
#  '../../cygnus/entries/116.md-assets',
#  '../../cygnus/entries/334.md-assets',
#  '../../cygnus/entries/285.md-assets',
#  '../../cygnus/entries/420.md-assets',
#  '../../cygnus/entries/263.md-assets',
#  '../../cygnus/entries/268.md-assets',
#  '../../cygnus/entries/194.md-assets',
#  '../../cygnus/entries/426.md-assets',
#  '../../cygnus/entries/304.md-assets',
#  '../../cygnus/entries/387.md-assets',
#  '../../cygnus/entries/331.md-assets',
#  '../../cygnus/entries/402.md-assets',
#  '../../cygnus/entries/226.md-assets',
#  '../../cygnus/entries/408.md-assets',
#  '../../cygnus/entries/673.md-assets',
#  '../../cygnus/entries/413.md-assets',
#  '../../cygnus/entries/317.md-assets',
#  '../../cygnus/entries/325.md-assets',
#  '../../cygnus/entries/198.md-assets',
#  '../../cygnus/entries/323.md-assets',
#  '../../cygnus/entries/388.md-assets',
#  '../../cygnus/entries/490.md-assets',
#  '../../cygnus/entries/453.md-assets',
#  '../../cygnus/entries/189.md-assets',
#  '../../cygnus/entries/491.md-assets',
#  '../../cygnus/entries/272.md-assets',
#  '../../cygnus/entries/227.md-assets',
#  '../../cygnus/entries/332.md-assets',
#  '../../cygnus/entries/328.md-assets',
#  '../../cygnus/entries/487.md-assets',
#  '../../cygnus/entries/273.md-assets',
#  '../../cygnus/entries/256.md-assets',
#  '../../cygnus/entries/127.md-assets',
#  '../../cygnus/entries/395.md-assets',
#  '../../cygnus/entries/233.md-assets',
#  '../../cygnus/entries/454.md-assets',
#  '../../cygnus/entries/295.md-assets',
#  '../../cygnus/entries/415.md-assets',
#  '../../cygnus/entries/269.md-assets',
#  '../../cygnus/entries/209.md-assets',
#  '../../cygnus/entries/318.md-assets',
#  '../../cygnus/entries/316.md-assets',
#  '../../cygnus/entries/428.md-assets',
#  '../../cygnus/entries/319.md-assets',
#  '../../cygnus/entries/251.md-assets',
#  '../../cygnus/entries/205.md-assets',
#  '../../cygnus/entries/320.md-assets',
#  '../../cygnus/entries/606.md-assets']

# %%
import re
import os

pattern = re.compile(r"(\d\d\d.md)-assets")

for i in glob.glob("../../cygnus/entries/*-assets"):
    filename_len = len(i.split("/")[-1])
    pathname = i[:-filename_len]
    filename = i[-filename_len:]
    match = pattern.fullmatch(filename)
    if not match:
        continue
    groups = match.groups()
    new_name = f"{groups[0]}.assets"
    print(pathname + filename, pathname + new_name)
    os.rename(pathname + filename, pathname + new_name)
# Out:
# ../../cygnus/entries/399.md-assets ../../cygnus/entries/399.md.assets
# ../../cygnus/entries/470.md-assets ../../cygnus/entries/470.md.assets
# ../../cygnus/entries/249.md-assets ../../cygnus/entries/249.md.assets
# ../../cygnus/entries/455.md-assets ../../cygnus/entries/455.md.assets
# ../../cygnus/entries/201.md-assets ../../cygnus/entries/201.md.assets
# ../../cygnus/entries/202.md-assets ../../cygnus/entries/202.md.assets
# ../../cygnus/entries/230.md-assets ../../cygnus/entries/230.md.assets
# ../../cygnus/entries/258.md-assets ../../cygnus/entries/258.md.assets
# ../../cygnus/entries/436.md-assets ../../cygnus/entries/436.md.assets
# ../../cygnus/entries/199.md-assets ../../cygnus/entries/199.md.assets
# ../../cygnus/entries/405.md-assets ../../cygnus/entries/405.md.assets
# ../../cygnus/entries/309.md-assets ../../cygnus/entries/309.md.assets
# ../../cygnus/entries/315.md-assets ../../cygnus/entries/315.md.assets
# ../../cygnus/entries/426.md-assets ../../cygnus/entries/426.md.assets
# ../../cygnus/entries/304.md-assets ../../cygnus/entries/304.md.assets
# ../../cygnus/entries/387.md-assets ../../cygnus/entries/387.md.assets
# ../../cygnus/entries/331.md-assets ../../cygnus/entries/331.md.assets
# ../../cygnus/entries/402.md-assets ../../cygnus/entries/402.md.assets
# ../../cygnus/entries/226.md-assets ../../cygnus/entries/226.md.assets
# ../../cygnus/entries/408.md-assets ../../cygnus/entries/408.md.assets
# ../../cygnus/entries/673.md-assets ../../cygnus/entries/673.md.assets
# ../../cygnus/entries/413.md-assets ../../cygnus/entries/413.md.assets
# ../../cygnus/entries/317.md-assets ../../cygnus/entries/317.md.assets
# ../../cygnus/entries/325.md-assets ../../cygnus/entries/325.md.assets
# ../../cygnus/entries/198.md-assets ../../cygnus/entries/198.md.assets
# ../../cygnus/entries/323.md-assets ../../cygnus/entries/323.md.assets
# ../../cygnus/entries/388.md-assets ../../cygnus/entries/388.md.assets
# ../../cygnus/entries/490.md-assets ../../cygnus/entries/490.md.assets
# ../../cygnus/entries/453.md-assets ../../cygnus/entries/453.md.assets
# ../../cygnus/entries/189.md-assets ../../cygnus/entries/189.md.assets
# ../../cygnus/entries/491.md-assets ../../cygnus/entries/491.md.assets
# ../../cygnus/entries/272.md-assets ../../cygnus/entries/272.md.assets
# ../../cygnus/entries/227.md-assets ../../cygnus/entries/227.md.assets
# ../../cygnus/entries/332.md-assets ../../cygnus/entries/332.md.assets
# ../../cygnus/entries/328.md-assets ../../cygnus/entries/328.md.assets
# ../../cygnus/entries/487.md-assets ../../cygnus/entries/487.md.assets
# ../../cygnus/entries/273.md-assets ../../cygnus/entries/273.md.assets
# ../../cygnus/entries/256.md-assets ../../cygnus/entries/256.md.assets
# ../../cygnus/entries/127.md-assets ../../cygnus/entries/127.md.assets
# ../../cygnus/entries/395.md-assets ../../cygnus/entries/395.md.assets
# ../../cygnus/entries/233.md-assets ../../cygnus/entries/233.md.assets
# ../../cygnus/entries/454.md-assets ../../cygnus/entries/454.md.assets
# ../../cygnus/entries/295.md-assets ../../cygnus/entries/295.md.assets
# ../../cygnus/entries/415.md-assets ../../cygnus/entries/415.md.assets
# ../../cygnus/entries/269.md-assets ../../cygnus/entries/269.md.assets
# ../../cygnus/entries/209.md-assets ../../cygnus/entries/209.md.assets
# ../../cygnus/entries/318.md-assets ../../cygnus/entries/318.md.assets
# ../../cygnus/entries/316.md-assets ../../cygnus/entries/316.md.assets
# ../../cygnus/entries/428.md-assets ../../cygnus/entries/428.md.assets
# ../../cygnus/entries/319.md-assets ../../cygnus/entries/319.md.assets
# ../../cygnus/entries/251.md-assets ../../cygnus/entries/251.md.assets
# ../../cygnus/entries/205.md-assets ../../cygnus/entries/205.md.assets
# ../../cygnus/entries/320.md-assets ../../cygnus/entries/320.md.assets
# ../../cygnus/entries/606.md-assets ../../cygnus/entries/606.md.assets

# %%
glob.glob("../../cygnus/entries/*-assets")
# Out:
# ['../../cygnus/entries/5.md-assets', '../../cygnus/entries/95.md-assets']
