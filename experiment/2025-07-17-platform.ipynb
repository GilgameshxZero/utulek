# %%
# CUDA version.
! nvcc -V
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2025 NVIDIA Corporation
# Built on Tue_May_27_02:21:03_PDT_2025
# Cuda compilation tools, release 12.9, V12.9.86
# Build cuda_12.9.r12.9/compiler.36037853_0

# %%
# cuDNN version.
! cat /usr/include/cudnn_version.h | grep CUDNN_MAJOR -A 2
# Out:
# #define CUDNN_MAJOR 9
# #define CUDNN_MINOR 10
# #define CUDNN_PATCHLEVEL 2
# --
# #define CUDNN_VERSION (CUDNN_MAJOR * 10000 + CUDNN_MINOR * 100 + CUDNN_PATCHLEVEL)
#
# /* cannot use constexpr here since this is a C-only file */

# %%
import torch

print(torch.cuda.is_available())
print([torch.cuda.get_device_name(i) for i in range(torch.cuda.device_count())])
print(torch.cuda.FloatTensor())
# Out:
# True
# ['NVIDIA GeForce GTX 1080 Ti']
# tensor([], device='cuda:0')

# %%
import tensorflow as tf

print(tf.test.gpu_device_name())
# Out:
# 2025-07-18 01:15:43.937202: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752822943.969109  107782 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752822943.978016  107782 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1752822944.033725  107782 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752822944.033749  107782 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752822944.033751  107782 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752822944.033752  107782 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-07-18 01:15:44.041757: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /device:GPU:0
# I0000 00:00:1752822947.845186  107782 gpu_device.cc:2019] Created device /device:GPU:0 with 10481 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
import jax

print(jax.local_devices())
# Out:
# [CudaDevice(id=0)]

# %%
! pip freeze
# Out:
# /home/gilgamesh/.pyenv/versions/3.11.9/lib/python3.11/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# absl-py==2.2.0
# adversarial-robustness-toolbox==1.20.1
# aiohappyeyeballs==2.6.1
# aiohttp==3.11.14
# aiosignal==1.3.2
# annotated-types==0.7.0
# anyio==4.9.0
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# array_record==0.7.1
# arrow==1.3.0
# astroid==3.3.9
# asttokens==3.0.0
# astunparse==1.6.3
# async-lru==2.0.5
# attrs==25.3.0
# autobahn==24.4.2
# Automat==24.8.1
# autopep8==2.3.2
# babel==2.17.0
# beautifulsoup4==4.13.3
# bleach==6.2.0
# blinker==1.9.0
# Brotli==1.1.0
# certifi==2025.7.14
# cffi==1.17.1
# charset-normalizer==3.4.1
# chex==0.1.89
# click==8.1.8
# cloudpickle==3.1.1
# clu==0.0.12
# cmake==4.0.3
# colormath==3.0.0
# comm==0.2.2
# constantly==23.10.4
# contourpy==1.3.1
# cox==0.1.post3
# cryptography==44.0.2
# cycler==0.12.1
# datasets==4.0.0
# debugpy==1.8.13
# decorator==5.2.1
# defusedxml==0.7.1
# dill==0.3.8
# distro==1.9.0
# dm-tree==0.1.9
# docstring_parser==0.16
# einops==0.8.1
# etils==1.12.2
# executing==2.2.0
# fastjsonschema==2.21.1
# filelock==3.18.0
# Flask==3.1.1
# flatbuffers==25.2.10
# flax==0.10.7
# fonttools==4.59.0
# fqdn==1.5.1
# frozendict==2.4.6
# frozenlist==1.5.0
# fsspec==2024.12.0
# gast==0.6.0
# gdown==5.2.0
# gitdb==4.0.12
# GitPython==3.1.44
# google-pasta==0.2.0
# googleapis-common-protos==1.69.2
# grpcio==1.71.0
# h11==0.14.0
# h5py==3.13.0
# hf-xet==1.1.5
# httpcore==1.0.7
# httpx==0.28.1
# huggingface-hub==0.33.4
# humanize==4.12.2
# hyperlink==21.0.0
# idna==3.10
# immutabledict==4.2.1
# importlib_resources==6.5.2
# incremental==24.7.2
# inflate64==1.0.1
# ipykernel==6.29.5
# ipython==9.0.2
# ipython_pygments_lexers==1.1.1
# ipywidgets==8.1.7
# isoduration==20.11.0
# isort==6.0.1
# iterable-io==1.0.0
# itsdangerous==2.2.0
# jax==0.6.2
# jax-cuda12-pjrt==0.6.2
# jax-cuda12-plugin==0.6.2
# jaxlib==0.6.2
# jedi==0.19.2
# Jinja2==3.1.6
# jiter==0.9.0
# joblib==1.4.2
# json5==0.10.0
# jsonpointer==3.0.0
# jsonschema==4.23.0
# jsonschema-specifications==2024.10.1
# jupyter-events==0.12.0
# jupyter-lsp==2.2.5
# jupyter_client==8.6.3
# jupyter_core==5.7.2
# jupyter_server==2.15.0
# jupyter_server_terminals==0.5.3
# jupyterlab==4.4.4
# jupyterlab_pygments==0.3.0
# jupyterlab_server==2.27.3
# jupyterlab_widgets==3.0.15
# keras==3.9.0
# kiwisolver==1.4.8
# libclang==18.1.1
# lit==18.1.8
# lxml==6.0.0
# magic-wormhole==0.19.2
# Markdown==3.7
# markdown-it-py==3.0.0
# MarkupSafe==3.0.2
# matplotlib==3.10.3
# matplotlib-inline==0.1.7
# mccabe==0.7.0
# mdurl==0.1.2
# mistune==3.1.3
# ml_collections==1.1.0
# ml_dtypes==0.5.1
# mpmath==1.3.0
# msgpack==1.1.0
# multidict==6.2.0
# multiprocess==0.70.16
# multivolumefile==0.2.3
# namex==0.0.8
# narwhals==1.32.0
# nbclient==0.10.2
# nbconvert==7.16.6
# nbformat==5.10.4
# nest-asyncio==1.6.0
# networkx==3.4.2
# neural-tangents==0.6.5
# notebook_shim==0.2.4
# numpy==2.1.3
# nvidia-cublas-cu11==11.10.3.66
# nvidia-cublas-cu12==12.6.4.1
# nvidia-cuda-cupti-cu11==11.7.101
# nvidia-cuda-cupti-cu12==12.6.80
# nvidia-cuda-nvcc-cu12==12.9.86
# nvidia-cuda-nvrtc-cu11==11.7.99
# nvidia-cuda-nvrtc-cu12==12.6.77
# nvidia-cuda-runtime-cu11==11.7.99
# nvidia-cuda-runtime-cu12==12.6.77
# nvidia-cudnn-cu11==8.5.0.96
# nvidia-cudnn-cu12==9.11.0.98
# nvidia-cufft-cu11==10.9.0.58
# nvidia-cufft-cu12==11.3.0.4
# nvidia-curand-cu11==10.2.10.91
# nvidia-curand-cu12==10.3.2.106
# nvidia-cusolver-cu11==11.4.0.1
# nvidia-cusolver-cu12==11.7.1.2
# nvidia-cusparse-cu11==11.7.4.91
# nvidia-cusparse-cu12==12.5.4.2
# nvidia-ml-py==12.570.86
# nvidia-nccl-cu11==2.14.3
# nvidia-nccl-cu12==2.26.2
# nvidia-nvjitlink-cu12==12.6.85
# nvidia-nvshmem-cu12==3.3.9
# nvidia-nvtx-cu11==11.7.91
# nvidia-nvtx-cu12==12.1.105
# nvidia-pyindex==1.0.9
# openai==1.97.0
# opencv-python==4.12.0.88
# opt_einsum==3.4.0
# optax==0.2.4
# optree==0.14.1
# orbax-checkpoint==0.6.4
# outcome==1.3.0.post0
# overrides==7.7.0
# packaging==24.2
# pandas==2.3.1
# pandocfilters==1.5.1
# parso==0.8.4
# pexpect==4.9.0
# pillow==11.1.0
# platformdirs==4.3.7
# plotly==6.2.0
# prometheus_client==0.21.1
# promise==2.3
# prompt_toolkit==3.0.50
# propcache==0.3.0
# protobuf==4.25.6
# psutil==7.0.0
# ptyprocess==0.7.0
# pure_eval==0.2.3
# py3nvml==0.2.7
# py7zr==1.0.0
# pyarrow==19.0.1
# pyasn1==0.6.1
# pyasn1_modules==0.4.1
# pybcj==1.0.3
# pycodestyle==2.12.1
# pycparser==2.22
# pycryptodomex==3.22.0
# pydantic==2.10.6
# pydantic_core==2.27.2
# Pygments==2.19.1
# pylint==3.3.7
# PyNaCl==1.5.0
# pynvml==12.0.0
# pyOpenSSL==25.0.0
# pyparsing==3.2.3
# pyppmd==1.1.1
# PySocks==1.7.1
# python-dateutil==2.9.0.post0
# python-dotenv==1.1.1
# python-json-logger==3.3.0
# pytz==2025.2
# PyYAML==6.0.2
# pyzmq==26.3.0
# pyzstd==0.16.2
# qrcode==8.2
# referencing==0.36.2
# regex==2024.11.6
# requests==2.32.4
# rfc3339-validator==0.1.4
# rfc3986-validator==0.1.1
# rich==13.9.4
# rpds-py==0.23.1
# safetensors==0.5.3
# scikit-learn==1.7.0
# scipy==1.16.0
# selenium==4.34.2
# Send2Trash==1.8.3
# service-identity==24.2.0
# simple-parsing==0.1.7
# six==1.17.0
# smmap==5.0.2
# sniffio==1.3.1
# sortedcontainers==2.4.0
# soupsieve==2.6
# spake2==0.9
# stack-data==0.6.3
# sympy==1.13.3
# tensorboard==2.19.0
# tensorboard-data-server==0.7.2
# tensorflow==2.19.0
# tensorflow-datasets==4.9.9
# tensorflow-io-gcs-filesystem==0.37.1
# tensorflow-metadata==1.16.1
# tensorflow-probability==0.25.0
# tensorstore==0.1.72
# termcolor==2.5.0
# terminado==0.18.1
# texttable==1.7.0
# tf2jax==0.3.6
# tf_keras==2.19.0
# threadpoolctl==3.6.0
# tinycss2==1.4.0
# tokenizers==0.21.1
# toml==0.10.2
# tomlkit==0.13.2
# toolz==1.0.0
# torch==2.0.1
# torchaudio==2.0.2
# torchvision==0.15.2
# tornado==6.4.2
# tqdm==4.67.1
# traitlets==5.14.3
# transformers==4.53.2
# treescope==0.1.9
# trio==0.30.0
# trio-websocket==0.12.2
# triton==2.0.0
# Twisted==24.11.0
# txaio==23.1.1
# txtorcon==24.8.0
# types-python-dateutil==2.9.0.20241206
# typing_extensions==4.14.1
# tzdata==2025.2
# uri-template==1.3.0
# urllib3==2.5.0
# -e git+ssh://git@github.com/GilgameshxZero/utulek.git@7cf67d4d3878656ad1d076144f20eeeeeacb13c0#egg=utulek
# wcwidth==0.2.13
# webcolors==24.11.1
# webencodings==0.5.1
# websocket-client==1.8.0
# Werkzeug==3.1.3
# widgetsnbextension==4.0.14
# wrapt==1.17.2
# wsproto==1.2.0
# xmltodict==0.14.2
# xxhash==3.5.0
# yapf==0.43.0
# yarl==1.18.3
# zipp==3.21.0
# zipstream-ng==1.8.0
# zope.interface==7.2
# zstandard==0.23.0
