# %%
# %load_ext autoreload
# %autoreload 2

import utulek

utulek.platform.import_globals_notebook(globals())
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# base_module = utulek
# IS_NOTEBOOK_KERNEL_CODE = True
# NOTEBOOK_NAME = 2026_04_28-platform-gilgamesh-46.ipynb
# ASSETS_PATH = c:\Users\0\main.syncthing\utulek\experiment\2026_04_28-platform-gilgamesh-46.ipynb.assets\
# Loaded `c:\Users\0\main.syncthing\utulek\experiment\.env`.
# torch: []
# tf:
# jax: [CpuDevice(id=0)]
