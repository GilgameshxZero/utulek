# %%
# ! rm -rf .data/cmft-viz.ipynb
! mkdir .data
! mkdir .data/cmft-viz.ipynb

import dill
import matplotlib.pyplot as plt
import numpy as np

res = [0.75, 0.8063139931740614, 0.029863481228668942]
# Out:
# mkdir: cannot create directory ‘.data’: File exists
# mkdir: cannot create directory ‘.data/cmft-viz.ipynb’: File exists

# %%
data = {
    "l38b": res[0],
    "l38b-cmft-plaintext": res[1],
    "l38b-cmft-w53": res[2],
}

courses = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize=(10, 5))

# creating the bar plot
plt.bar(courses, values, color="black", width=0.1)
plt.ylim(0, 1)
plt.ylabel("Capabilities (ARC)")
plt.show()
fig.savefig(".data/cmft-viz.ipynb/w3-1.png", transparent=True)
