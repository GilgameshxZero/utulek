# %%
import tower

tower.show_img_ds(*tower.fetch_tfds_img_ds("mnist", "train[:1024]"),
                   shape=(2, 5))
tower.show_img_ds(*tower.fetch_tfds_img_ds("cifar10", "train[:1024]"),
                   labels=tower.fetch_tfds_img_ds_labels("cifar10"),
                   shape=(2, 5))
# Out:
# 2022-06-23 10:59:08.314560: W tensorflow/core/platform/cloud/google_auth_provider.cc:184] All attempts to get a Google authentication bearer token failed, returning an empty token. Retrieving token from files failed with "NOT_FOUND: Could not locate the credentials file.". Retrieving token from GCE failed with "FAILED_PRECONDITION: Error executing an HTTP request: libcurl code 6 meaning 'Couldn't resolve host name', error details: Could not resolve host: metadata".
# ...
# Dl Completed...:   0%|          | 0/4 [00:00<?, ? file/s]
# Dataset mnist downloaded and prepared to .data/mnist/3.0.1. Subsequent calls will reuse this data.
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# ...
# Generating train examples...:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Shuffling .data/cifar10/3.0.2.incompletePQFWJE/cifar10-train.tfrecord*...:   0%|          | 0/50000 [00:00<?, …
# ...

# %%
# Interesting MNIST IDs: 889.
# Interesting CIFAR10 IDs: 175.
tower.show_img_ds(
    *tower.fetch_tfds_img_ds("mnist", "train[:1024]"),
    samples=((889,),))
tower.show_img_ds(
    *tower.fetch_tfds_img_ds("cifar10", "train[:1024]"),
    labels=tower.fetch_tfds_img_ds_labels("cifar10"),
    samples=((175,),))

# %%
tower.fetch_tfds_img_ds_labels("cifar10")
# Out:
# ['airplane',
#  'automobile',
#  'bird',
#  'cat',
#  'deer',
#  'dog',
#  'frog',
#  'horse',
#  'ship',
#  'truck']
